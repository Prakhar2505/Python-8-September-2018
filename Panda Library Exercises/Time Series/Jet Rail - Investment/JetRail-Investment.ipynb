# %% [markdown]
# # Jet Rail - Time Series forecasting

# %% [markdown]
# ### Load the dataset into panda's dataframe

# %%
import pandas as pd

# %%
data = pd.read_csv('data/Train.csv')
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %% [markdown]
# ### Compute the difference between data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18288 entries, 0 to 18287
# Data columns (total 3 columns):
# ID          18288 non-null int64
# Datetime    18288 non-null object
# Count       18288 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 428.7+ KB

# %%
data['Datetime'] = pd.to_datetime(data['Datetime'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18288 entries, 0 to 18287
# Data columns (total 3 columns):
# ID          18288 non-null int64
# Datetime    18288 non-null datetime64[ns]
# Count       18288 non-null int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 428.7 KB

# %%
data.head()
# Out:
#    ID            Datetime  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %%
data.Datetime.diff()
# Out:
# 0            NaT
# 1       01:00:00
# 2       01:00:00
# 3       01:00:00
# 4       01:00:00
# 5       01:00:00
# 6       01:00:00
# 7       01:00:00
# 8       01:00:00
# 9       01:00:00
# 10      01:00:00
# 11      01:00:00
# 12      01:00:00
# 13      01:00:00
# 14      01:00:00
# 15      01:00:00
# 16      01:00:00
# 17      01:00:00
# 18      01:00:00
# 19      01:00:00
# 20      01:00:00
# 21      01:00:00
# 22      01:00:00
# 23      01:00:00
# 24      01:00:00
# 25      01:00:00
# 26      01:00:00
# 27      01:00:00
# 28      01:00:00
# 29      01:00:00
#           ...
# 18258   01:00:00
# 18259   01:00:00
# 18260   01:00:00
# 18261   01:00:00
# 18262   01:00:00
# 18263   01:00:00
# 18264   01:00:00
# 18265   01:00:00
# 18266   01:00:00
# 18267   01:00:00
# 18268   01:00:00
# 18269   01:00:00
# 18270   01:00:00
# 18271   01:00:00
# 18272   01:00:00
# 18273   01:00:00
# 18274   01:00:00
# 18275   01:00:00
# 18276   01:00:00
# 18277   01:00:00
# 18278   01:00:00
# 18279   01:00:00
# 18280   01:00:00
# 18281   01:00:00
# 18282   01:00:00
# 18283   01:00:00
# 18284   01:00:00
# 18285   01:00:00
# 18286   01:00:00
# 18287   01:00:00
# Name: Datetime, Length: 18288, dtype: timedelta64[ns]

# %%
data = data.set_index(data['Datetime'])
data.head()
# Out:
#                      ID            Datetime  Count
# Datetime
# 2012-08-25 00:00:00   0 2012-08-25 00:00:00      8
# 2012-08-25 01:00:00   1 2012-08-25 01:00:00      2
# 2012-08-25 02:00:00   2 2012-08-25 02:00:00      6
# 2012-08-25 03:00:00   3 2012-08-25 03:00:00      2
# 2012-08-25 04:00:00   4 2012-08-25 04:00:00      2

# %%
data.drop(['Datetime'], axis=1, inplace=True)
data.head()
# Out:
#                      ID  Count
# Datetime
# 2012-08-25 00:00:00   0      8
# 2012-08-25 01:00:00   1      2
# 2012-08-25 02:00:00   2      6
# 2012-08-25 03:00:00   3      2
# 2012-08-25 04:00:00   4      2

# %%
data.diff()
# Out:
#                       ID  Count
# Datetime
# 2012-08-25 00:00:00  NaN    NaN
# 2012-08-25 01:00:00  1.0   -6.0
# 2012-08-25 02:00:00  1.0    4.0
# 2012-08-25 03:00:00  1.0   -4.0
# 2012-08-25 04:00:00  1.0    0.0
# 2012-08-25 05:00:00  1.0    0.0
# 2012-08-25 06:00:00  1.0    0.0
# 2012-08-25 07:00:00  1.0    0.0
# 2012-08-25 08:00:00  1.0    4.0
# 2012-08-25 09:00:00  1.0   -4.0
# 2012-08-25 10:00:00  1.0    0.0
# 2012-08-25 11:00:00  1.0    4.0
# 2012-08-25 12:00:00  1.0   -2.0
# 2012-08-25 13:00:00  1.0   -2.0
# 2012-08-25 14:00:00  1.0    4.0
# 2012-08-25 15:00:00  1.0   -4.0
# 2012-08-25 16:00:00  1.0    0.0
# 2012-08-25 17:00:00  1.0    0.0
# 2012-08-25 18:00:00  1.0    0.0
# 2012-08-25 19:00:00  1.0    0.0
# 2012-08-25 20:00:00  1.0    0.0
# 2012-08-25 21:00:00  1.0    4.0
# 2012-08-25 22:00:00  1.0   -4.0
# 2012-08-25 23:00:00  1.0    0.0
# 2012-08-26 00:00:00  1.0    2.0
# 2012-08-26 01:00:00  1.0    2.0
# 2012-08-26 02:00:00  1.0   -4.0
# 2012-08-26 03:00:00  1.0    2.0
# 2012-08-26 04:00:00  1.0   -2.0
# 2012-08-26 05:00:00  1.0    0.0
# ...                  ...    ...
# 2014-09-24 18:00:00  1.0  -88.0
# 2014-09-24 19:00:00  1.0  212.0
# 2014-09-24 20:00:00  1.0 -170.0
# 2014-09-24 21:00:00  1.0  -72.0
# 2014-09-24 22:00:00  1.0  -88.0
# 2014-09-24 23:00:00  1.0   94.0
# 2014-09-25 00:00:00  1.0 -256.0
# 2014-09-25 01:00:00  1.0 -140.0
# 2014-09-25 02:00:00  1.0    4.0
# 2014-09-25 03:00:00  1.0 -134.0
# 2014-09-25 04:00:00  1.0  -72.0
# 2014-09-25 05:00:00  1.0  -10.0
# 2014-09-25 06:00:00  1.0   82.0
# 2014-09-25 07:00:00  1.0   82.0
# 2014-09-25 08:00:00  1.0  -16.0
# 2014-09-25 09:00:00  1.0   30.0
# 2014-09-25 10:00:00  1.0  212.0
# 2014-09-25 11:00:00  1.0  -68.0
# 2014-09-25 12:00:00  1.0   16.0
# 2014-09-25 13:00:00  1.0  -30.0
# 2014-09-25 14:00:00  1.0  -26.0
# 2014-09-25 15:00:00  1.0   70.0
# 2014-09-25 16:00:00  1.0  -32.0
# 2014-09-25 17:00:00  1.0  -32.0
# 2014-09-25 18:00:00  1.0   58.0
# 2014-09-25 19:00:00  1.0  188.0
# 2014-09-25 20:00:00  1.0 -136.0
# 2014-09-25 21:00:00  1.0  -30.0
# 2014-09-25 22:00:00  1.0 -122.0
# 2014-09-25 23:00:00  1.0  -46.0
#
# [18288 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 10))
plt.plot(data.Count)
plt.show()

# %% [markdown]
# ### Exploratory Data Analysis

# %% [raw]
# 1. Yearly data group.
# 2. Month wise.
# 3. Hour wise.
# 4. Daily.
# 5. Weekly.

# %%
yearly_data = data.resample('Y').sum()
yearly_data.head()
# Out:
#                   ID    Count
# Datetime
# 2012-12-31   4791060    34932
# 2013-12-31  65485380   685968
# 2014-12-31  96939888  1820366

# %%
yearly_data.drop(['ID'], axis=1, inplace=True)
yearly_data.head()
# Out:
#               Count
# Datetime
# 2012-12-31    34932
# 2013-12-31   685968
# 2014-12-31  1820366

# %%
plt.figure(figsize=(12, 10))
yearly_data.plot.bar()

font = {
    'family': 'serif',
    'weight': 'bold',
    'size': 20
}
# plt.xticks(ticks=[2012, 2013, 2014], labels=['2012', '2013', '2014'])
plt.xlabel('Years', fontdict=font)
plt.ylabel('Number of people', fontdict=font)
plt.title('Yearly count of people', fontdict=font)
plt.savefig('yearly-count.png')
plt.show()

# %%
monthly_data = data.groupby(data.index.month).sum()
monthly_data
# Out:
#                 ID   Count
# Datetime
# 1         12645612  166530
# 2         12052980  165960
# 3         13965804  171404
# 4         14161092  203708
# 5         15329772  244540
# 6         15454788  235728
# 7         16693740  269496
# 8         17400696  316020
# 9         15494088  290694
# 10        10761516  158982
# 11        11130756  158104
# 12        12125484  160100

# %%
monthly_data.drop(['ID'], axis=1, inplace=True)
monthly_data.head()
# Out:
#            Count
# Datetime
# 1         166530
# 2         165960
# 3         171404
# 4         203708
# 5         244540

# %%
plt.figure(figsize=(12, 10))
monthly_data.plot.bar()

font = {
    'family': 'serif',
    'weight': 'bold',
    'size': 20
}
# plt.xticks(ticks=[2012, 2013, 2014], labels=['2012', '2013', '2014'])
plt.xlabel('Years', fontdict=font)
plt.ylabel('Number of people', fontdict=font)
plt.title('Yearly count of people', fontdict=font)
plt.savefig('yearly-count.png')
plt.show()
