# %% [markdown]
# # Jet Rail Investment

# %% [markdown]
# ### Problem Definition

# %% [raw]
# Reliance Industries, want to invest in new Metro rails. The investment is about 100 crores. As per the previous records of Metro Rail, tell the companies if the investment would be good or not. Taking into consideration, the previous data and by what time, can they expect the return of investment.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd

# %%
data = pd.read_csv('data/Train.csv')
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18288 entries, 0 to 18287
# Data columns (total 3 columns):
# ID          18288 non-null int64
# Datetime    18288 non-null object
# Count       18288 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 428.7+ KB

# %% [markdown]
# ### Convert the datetime column to Datetime

# %%
data['Datetime'] = pd.to_datetime(data['Datetime'], format='%d-%m-%Y %H:%M')
data.head()
# Out:
#    ID            Datetime  Count
# 0   0 2012-08-25 00:00:00      8
# 1   1 2012-08-25 01:00:00      2
# 2   2 2012-08-25 02:00:00      6
# 3   3 2012-08-25 03:00:00      2
# 4   4 2012-08-25 04:00:00      2

# %% [markdown]
# ### Find the intervals between the collection of data

# %%
data.Datetime.diff()
# Out:
# 0            NaT
# 1       01:00:00
# 2       01:00:00
# 3       01:00:00
# 4       01:00:00
# 5       01:00:00
# 6       01:00:00
# 7       01:00:00
# 8       01:00:00
# 9       01:00:00
# 10      01:00:00
# 11      01:00:00
# 12      01:00:00
# 13      01:00:00
# 14      01:00:00
# 15      01:00:00
# 16      01:00:00
# 17      01:00:00
# 18      01:00:00
# 19      01:00:00
# 20      01:00:00
# 21      01:00:00
# 22      01:00:00
# 23      01:00:00
# 24      01:00:00
# 25      01:00:00
# 26      01:00:00
# 27      01:00:00
# 28      01:00:00
# 29      01:00:00
#           ...
# 18258   01:00:00
# 18259   01:00:00
# 18260   01:00:00
# 18261   01:00:00
# 18262   01:00:00
# 18263   01:00:00
# 18264   01:00:00
# 18265   01:00:00
# 18266   01:00:00
# 18267   01:00:00
# 18268   01:00:00
# 18269   01:00:00
# 18270   01:00:00
# 18271   01:00:00
# 18272   01:00:00
# 18273   01:00:00
# 18274   01:00:00
# 18275   01:00:00
# 18276   01:00:00
# 18277   01:00:00
# 18278   01:00:00
# 18279   01:00:00
# 18280   01:00:00
# 18281   01:00:00
# 18282   01:00:00
# 18283   01:00:00
# 18284   01:00:00
# 18285   01:00:00
# 18286   01:00:00
# 18287   01:00:00
# Name: Datetime, Length: 18288, dtype: timedelta64[ns]

# %% [markdown]
# ### Visualize the data

# %%
data = data.set_index(data['Datetime'])
data.head()
# Out:
#                      ID            Datetime  Count
# Datetime
# 2012-08-25 00:00:00   0 2012-08-25 00:00:00      8
# 2012-08-25 01:00:00   1 2012-08-25 01:00:00      2
# 2012-08-25 02:00:00   2 2012-08-25 02:00:00      6
# 2012-08-25 03:00:00   3 2012-08-25 03:00:00      2
# 2012-08-25 04:00:00   4 2012-08-25 04:00:00      2

# %%
data.drop(['Datetime'], axis=1, inplace=True)
data.head()
# Out:
#                      ID  Count
# Datetime
# 2012-08-25 00:00:00   0      8
# 2012-08-25 01:00:00   1      2
# 2012-08-25 02:00:00   2      6
# 2012-08-25 03:00:00   3      2
# 2012-08-25 04:00:00   4      2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 8))
plt.plot(data.Count)
plt.legend()
plt.xlabel('Year', fontdict=font_dict)
plt.ylabel('Count', fontdict=font_dict)
plt.title('Increase in Passengers Count', fontdict=font_dict)
plt.savefig('Visualization/Visualize-data.png')
plt.show()

# %%
yearly_data = data.resample('Y').sum()
yearly_data.head()
# Out:
#                   ID    Count
# Datetime
# 2012-12-31   4791060    34932
# 2013-12-31  65485380   685968
# 2014-12-31  96939888  1820366

# %%
yearly_data.index = ['2012', '2013', '2014']
yearly_data
# Out:
#             ID    Count
# 2012   4791060    34932
# 2013  65485380   685968
# 2014  96939888  1820366

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 8))
yearly_data.Count.plot.bar()
plt.legend(loc='upper left')
plt.xlabel('Year', fontdict=font_dict)
plt.xticks(rotation=0)
plt.ylabel('Count', fontdict=font_dict)
plt.title('Passengers Increase over Years', fontdict=font_dict)
plt.savefig('Visualization/Passengers-Count-Year-Wise.png')
plt.show()

# %%
monthly_data = data.resample('M').sum()
monthly_data.head()
# Out:
#                  ID  Count
# Datetime
# 2012-08-31    14028    496
# 2012-09-30   379800   3200
# 2012-10-31   937068   8174
# 2012-11-30  1433880  11396
# 2012-12-31  2026284  11666

# %%
monthly_data = data.groupby(data.index.month).sum()
monthly_data.head()
# Out:
#                 ID   Count
# Datetime
# 1         11677080  138112
# 2         11498592  149448
# 3         13784088  154442
# 4         14393520  198260
# 5         15962520  230722

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 8))
monthly_data.Count.plot.bar()
plt.xlabel('Months', fontdict=font_dict)
plt.xticks(rotation=0)
plt.ylabel('Count', fontdict=font_dict)
plt.title('Monthly-Passengers-Count')
plt.savefig('Visualization/Monthly-Passengers-Count.png')
plt.show()

# %%
daily_data = data.groupby(data.index.weekday).sum()
daily_data
# Out:
#                 ID   Count
# Datetime
# 0         23888004  412916
# 1         23950788  430988
# 2         24013572  427022
# 3         24076356  407250
# 4         23699952  375122
# 5         23762436  251292
# 6         23825220  236676

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 8))
daily_data.Count.plot.bar()
plt.xlabel('Day of Week', fontdict=font_dict)
plt.xticks(rotation=0)
plt.ylabel('Count', fontdict=font_dict)
plt.title('Passenger-Count-WeekDay-Wise', fontdict=font_dict)
plt.savefig('Visualization/Passenger-Count-Daily.png')
plt.show()

# %%
week_day = data.groupby(data.index.weekday_name).sum()
week_day
# Out:
#                  ID   Count
# Datetime
# Friday     23699952  375122
# Monday     23888004  412916
# Saturday   23762436  251292
# Sunday     23825220  236676
# Thursday   24076356  407250
# Tuesday    23950788  430988
# Wednesday  24013572  427022

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 8))
week_day.Count.plot.bar()
plt.xlabel('Year', fontdict=font_dict)
plt.ylabel('Count', fontdict=font_dict)
plt.xticks(rotation=0)
plt.title('Passenger-Count-Week-Number')
plt.savefig('Visualization/Passenger-Count-Week-Number.png')
plt.show()

# %%
hourly_data = data.groupby(data.index.hour).sum()
hourly_data
# Out:
#                ID   Count
# Datetime
# 0         6958584  112544
# 1         6959346   89816
# 2         6960108   76012
# 3         6960870   62806
# 4         6961632   52864
# 5         6962394   47322
# 6         6963156   50884
# 7         6963918   59012
# 8         6964680   67956
# 9         6965442   87814
# 10        6966204  124642
# 11        6966966  138182
# 12        6967728  139646
# 13        6968490  123506
# 14        6969252  132058
# 15        6970014  130390
# 16        6970776  127062
# 17        6971538  130022
# 18        6972300  133222
# 19        6973062  141362
# 20        6973824  135844
# 21        6974586  126796
# 22        6975348  127256
# 23        6976110  124248

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 10))
hourly_data.Count.plot.bar()
plt.xlabel('Hours', fontdict=font_dict)
plt.xticks(rotation=0)
plt.ylabel('Passenger Count', fontdict=font_dict)
plt.title('Passenger Count-Month Wise', fontdict=font_dict)
plt.savefig('Visualization/Passenger-Count-Month-Wise.png')
plt.show()

# %% [markdown]
# ### Resample the data to daily users

# %%
daily_data = data.resample('D').mean()
daily_data.head()
# Out:
#                ID     Count
# Datetime
# 2012-08-25   11.5  3.166667
# 2012-08-26   35.5  3.666667
# 2012-08-27   59.5  2.583333
# 2012-08-28   83.5  2.416667
# 2012-08-29  107.5  2.500000

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 8))
daily_data.Count.plot()
plt.xlabel('Year', fontdict=font_dict)
plt.ylabel('Average Passenger Count', fontdict=font_dict)
plt.title('Average increase in Daily Passenger Count', fontdict=font_dict)
plt.savefig('Visualization/Average-Daily-Passenger-Count.png')
plt.show()

# %% [markdown]
# ### Split the data into train and validation data

# %%
training_data = daily_data.loc[:'2014-06-24']
validation_data = daily_data.loc['2014-06-25':]
training_data.tail()
# Out:
#                  ID       Count
# Datetime
# 2014-06-20  15947.5  379.916667
# 2014-06-21  15971.5  220.083333
# 2014-06-22  15995.5  230.833333
# 2014-06-23  16019.5  419.416667
# 2014-06-24  16043.5  372.166667

# %%
validation_data.head()
# Out:
#                  ID       Count
# Datetime
# 2014-06-25  16067.5  353.666667
# 2014-06-26  16091.5  395.250000
# 2014-06-27  16115.5  282.333333
# 2014-06-28  16139.5  218.250000
# 2014-06-29  16163.5  196.250000

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 10))
training_data.Count.plot(label='Observed')
validation_data.Count.plot(label='Validation')
plt.xlabel('Yearly Data', fontdict = font_dict)
plt.ylabel('Average Passengers Count', fontdict = font_dict)
plt.legend()
plt.title('Average Passenger Count-Yearly', fontdict = font_dict)
plt.savefig('Visualization/Average-Passenger-Count-Observed-vs-Validation.png')
plt.show()

# %% [markdown]
# ## Forecasting Methods

# %% [raw]
# When there is only level -
# 1. Naive Approach.
# 2. Simple Average.
# 3. Moving Average.
# 4. Simple Exponential Method.

# %% [raw]
# When there is level + trend -
# 1. Holt's Linear Trend Model.
# 2. Linear Regression.

# %% [raw]
# When there is level + trend + seasonality -
# 1. Holt's Winter Trend Model.

# %% [markdown]
# ### Important Terms -

# %% [raw]
# 1. Level - The average value in the series.
# 2. Trend - The increasing or decreasing value in the series.
# 3. Seasonality - The repeating short-term cycle in the series.
# 4. Noise - The random variation in the dataset.

# %% [markdown]
# #### Note:

# %% [raw]
# Both Trend and Seasonality are Additive and Multiplicative over time which means, their value increase either linearlly or exponentially over time.

# %%
from IPython.display import Image
Image("Trend-Seasonality-Additive-Multiplicative.png")

# %% [markdown]
# ### View all the above mentioned terms in our data set.

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
terms = seasonal_decompose(daily_data, model='additive')
# Out:
# c:\users\jatinder\appdata\local\programs\python\python36\lib\site-packages\scipy\signal\signaltools.py:491: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return x[reverse].conj()

# %% [raw]
# Additive = Seasonal Effect + Trend + Cyclic + Residual
#
# Assumes that data for each month is same as throughtout the year.

# %% [raw]
# Multiplicative = (Seasonal Effect) * Trend * Cyclic * Residual
#
# Assumes that the data value difference are in the same proportion through out different years.

# %%
print("Level/Observed in the dataset is: ", terms.observed)
print("Trend in the dataset is: ", terms.trend)
print("Seasonal in the dataset is: ", terms.seasonal)
print("Noise/Residual in the dataset is: ", terms.resid)
# Out:
# Level/Observed in the dataset is:                   ID       Count
# Datetime
# 2012-08-25     11.5    3.166667
# 2012-08-26     35.5    3.666667
# 2012-08-27     59.5    2.583333
# 2012-08-28     83.5    2.416667
# 2012-08-29    107.5    2.500000
# 2012-08-30    131.5    3.083333
# 2012-08-31    155.5    3.250000
# 2012-09-01    179.5    4.666667
# 2012-09-02    203.5    4.916667
# 2012-09-03    227.5    4.500000
# 2012-09-04    251.5    2.750000
# 2012-09-05    275.5    4.333333
# 2012-09-06    299.5    4.166667
# 2012-09-07    323.5    2.833333
# 2012-09-08    347.5    4.166667
# 2012-09-09    371.5    2.833333
# 2012-09-10    395.5    2.666667
# 2012-09-11    419.5    2.416667
# 2012-09-12    443.5    3.500000
# 2012-09-13    467.5    3.000000
# 2012-09-14    491.5    3.500000
# 2012-09-15    515.5    3.833333
# 2012-09-16    539.5    2.916667
# 2012-09-17    563.5    3.833333
# 2012-09-18    587.5    7.833333
# 2012-09-19    611.5    6.583333
# 2012-09-20    635.5    3.500000
# 2012-09-21    659.5    3.750000
# 2012-09-22    683.5    3.250000
# 2012-09-23    707.5    4.250000
# ...             ...         ...
# 2014-08-27  17579.5  520.666667
# 2014-08-28  17603.5  379.250000
# 2014-08-29  17627.5  413.750000
# 2014-08-30  17651.5  352.583333
# 2014-08-31  17675.5  290.166667
# 2014-09-01  17699.5  436.000000
# 2014-09-02  17723.5  573.500000
# 2014-09-03  17747.5  509.000000
# 2014-09-04  17771.5  446.000000
# 2014-09-05  17795.5  532.500000
# 2014-09-06  17819.5  339.833333
# 2014-09-07  17843.5  286.500000
# 2014-09-08  17867.5  426.000000
# 2014-09-09  17891.5  546.000000
# 2014-09-10  17915.5  483.000000
# 2014-09-11  17939.5  424.166667
# 2014-09-12  17963.5  375.416667
# 2014-09-13  17987.5  253.333333
# 2014-09-14  18011.5  238.166667
# 2014-09-15  18035.5  445.333333
# 2014-09-16  18059.5  670.000000
# 2014-09-17  18083.5  569.833333
# 2014-09-18  18107.5  458.333333
# 2014-09-19  18131.5  543.083333
# 2014-09-20  18155.5  341.083333
# 2014-09-21  18179.5  379.250000
# 2014-09-22  18203.5  588.166667
# 2014-09-23  18227.5  554.333333
# 2014-09-24  18251.5  702.333333
# 2014-09-25  18275.5  589.666667
#
# [762 rows x 2 columns]
# Trend in the dataset is:                   ID       Count
# Datetime
# 2012-08-25      NaN         NaN
# 2012-08-26      NaN         NaN
# 2012-08-27      NaN         NaN
# 2012-08-28     83.5    2.952381
# 2012-08-29    107.5    3.166667
# 2012-08-30    131.5    3.345238
# 2012-08-31    155.5    3.619048
# 2012-09-01    179.5    3.666667
# 2012-09-02    203.5    3.928571
# 2012-09-03    227.5    4.083333
# 2012-09-04    251.5    4.023810
# 2012-09-05    275.5    3.952381
# 2012-09-06    299.5    3.654762
# 2012-09-07    323.5    3.392857
# 2012-09-08    347.5    3.345238
# 2012-09-09    371.5    3.226190
# 2012-09-10    395.5    3.059524
# 2012-09-11    419.5    3.154762
# 2012-09-12    443.5    3.107143
# 2012-09-13    467.5    3.119048
# 2012-09-14    491.5    3.285714
# 2012-09-15    515.5    4.059524
# 2012-09-16    539.5    4.500000
# 2012-09-17    563.5    4.571429
# 2012-09-18    587.5    4.607143
# 2012-09-19    611.5    4.523810
# 2012-09-20    635.5    4.714286
# 2012-09-21    659.5    5.130952
# 2012-09-22    683.5    4.964286
# 2012-09-23    707.5    4.726190
# ...             ...         ...
# 2014-08-27  17579.5  420.380952
# 2014-08-28  17603.5  418.023810
# 2014-08-29  17627.5  416.238095
# 2014-08-30  17651.5  423.702381
# 2014-08-31  17675.5  422.035714
# 2014-09-01  17699.5  431.571429
# 2014-09-02  17723.5  448.535714
# 2014-09-03  17747.5  446.714286
# 2014-09-04  17771.5  446.190476
# 2014-09-05  17795.5  444.761905
# 2014-09-06  17819.5  440.833333
# 2014-09-07  17843.5  437.119048
# 2014-09-08  17867.5  434.000000
# 2014-09-09  17891.5  411.559524
# 2014-09-10  17915.5  399.202381
# 2014-09-11  17939.5  392.297619
# 2014-09-12  17963.5  395.059524
# 2014-09-13  17987.5  412.773810
# 2014-09-14  18011.5  425.178571
# 2014-09-15  18035.5  430.059524
# 2014-09-16  18059.5  454.011905
# 2014-09-17  18083.5  466.547619
# 2014-09-18  18107.5  486.702381
# 2014-09-19  18131.5  507.107143
# 2014-09-20  18155.5  490.583333
# 2014-09-21  18179.5  509.511905
# 2014-09-22  18203.5  528.273810
# 2014-09-23      NaN         NaN
# 2014-09-24      NaN         NaN
# 2014-09-25      NaN         NaN
#
# [762 rows x 2 columns]
# Seasonal in the dataset is:                        ID      Count
# Datetime
# 2012-08-25  6.005402e-13 -41.266109
# 2012-08-26 -2.892172e-13 -47.835333
# 2012-08-27  2.463215e-13  19.392621
# 2012-08-28 -1.185554e-13  25.406069
# 2012-08-29 -1.090815e-13  22.058626
# 2012-08-30 -2.123733e-13  14.976946
# 2012-08-31 -1.176343e-13   7.267180
# 2012-09-01  6.005402e-13 -41.266109
# 2012-09-02 -2.892172e-13 -47.835333
# 2012-09-03  2.463215e-13  19.392621
# 2012-09-04 -1.185554e-13  25.406069
# 2012-09-05 -1.090815e-13  22.058626
# 2012-09-06 -2.123733e-13  14.976946
# 2012-09-07 -1.176343e-13   7.267180
# 2012-09-08  6.005402e-13 -41.266109
# 2012-09-09 -2.892172e-13 -47.835333
# 2012-09-10  2.463215e-13  19.392621
# 2012-09-11 -1.185554e-13  25.406069
# 2012-09-12 -1.090815e-13  22.058626
# 2012-09-13 -2.123733e-13  14.976946
# 2012-09-14 -1.176343e-13   7.267180
# 2012-09-15  6.005402e-13 -41.266109
# 2012-09-16 -2.892172e-13 -47.835333
# 2012-09-17  2.463215e-13  19.392621
# 2012-09-18 -1.185554e-13  25.406069
# 2012-09-19 -1.090815e-13  22.058626
# 2012-09-20 -2.123733e-13  14.976946
# 2012-09-21 -1.176343e-13   7.267180
# 2012-09-22  6.005402e-13 -41.266109
# 2012-09-23 -2.892172e-13 -47.835333
# ...                  ...        ...
# 2014-08-27 -1.090815e-13  22.058626
# 2014-08-28 -2.123733e-13  14.976946
# 2014-08-29 -1.176343e-13   7.267180
# 2014-08-30  6.005402e-13 -41.266109
# 2014-08-31 -2.892172e-13 -47.835333
# 2014-09-01  2.463215e-13  19.392621
# 2014-09-02 -1.185554e-13  25.406069
# 2014-09-03 -1.090815e-13  22.058626
# 2014-09-04 -2.123733e-13  14.976946
# 2014-09-05 -1.176343e-13   7.267180
# 2014-09-06  6.005402e-13 -41.266109
# 2014-09-07 -2.892172e-13 -47.835333
# 2014-09-08  2.463215e-13  19.392621
# 2014-09-09 -1.185554e-13  25.406069
# 2014-09-10 -1.090815e-13  22.058626
# 2014-09-11 -2.123733e-13  14.976946
# 2014-09-12 -1.176343e-13   7.267180
# 2014-09-13  6.005402e-13 -41.266109
# 2014-09-14 -2.892172e-13 -47.835333
# 2014-09-15  2.463215e-13  19.392621
# 2014-09-16 -1.185554e-13  25.406069
# 2014-09-17 -1.090815e-13  22.058626
# 2014-09-18 -2.123733e-13  14.976946
# 2014-09-19 -1.176343e-13   7.267180
# 2014-09-20  6.005402e-13 -41.266109
# 2014-09-21 -2.892172e-13 -47.835333
# 2014-09-22  2.463215e-13  19.392621
# 2014-09-23 -1.185554e-13  25.406069
# 2014-09-24 -1.090815e-13  22.058626
# 2014-09-25 -2.123733e-13  14.976946
#
# [762 rows x 2 columns]
# Noise/Residual in the dataset is:                        ID       Count
# Datetime
# 2012-08-25           NaN         NaN
# 2012-08-26           NaN         NaN
# 2012-08-27           NaN         NaN
# 2012-08-28  1.327662e-13  -25.941783
# 2012-08-29  1.232923e-13  -22.725293
# 2012-08-30  2.123733e-13  -15.238851
# 2012-08-31  1.176343e-13   -7.636228
# 2012-09-01 -5.721185e-13   42.266109
# 2012-09-02  2.892172e-13   48.823428
# 2012-09-03 -2.178998e-13  -18.975954
# 2012-09-04  1.185554e-13  -26.679878
# 2012-09-05  1.090815e-13  -21.677674
# 2012-09-06  2.123733e-13  -14.465042
# 2012-09-07  1.176343e-13   -7.826704
# 2012-09-08 -6.005402e-13   42.087538
# 2012-09-09  2.892172e-13   47.442476
# 2012-09-10 -1.894781e-13  -19.785478
# 2012-09-11  1.185554e-13  -26.144164
# 2012-09-12  1.090815e-13  -21.665769
# 2012-09-13  2.123733e-13  -15.095994
# 2012-09-14  1.176343e-13   -7.052894
# 2012-09-15 -6.005402e-13   41.039919
# 2012-09-16  2.892172e-13   46.252000
# 2012-09-17 -2.463215e-13  -20.130716
# 2012-09-18  1.185554e-13  -22.179878
# 2012-09-19  2.227683e-13  -19.999102
# 2012-09-20  2.123733e-13  -16.191232
# 2012-09-21  1.176343e-13   -8.648132
# 2012-09-22 -6.005402e-13   39.551824
# 2012-09-23  2.892172e-13   47.359143
# ...                  ...         ...
# 2014-08-27  1.090815e-13   78.227088
# 2014-08-28  2.123733e-13  -53.750756
# 2014-08-29  1.176343e-13   -9.755275
# 2014-08-30 -6.005402e-13  -29.852938
# 2014-08-31  2.892172e-13  -84.033714
# 2014-09-01 -2.463215e-13  -14.964050
# 2014-09-02  1.185554e-13   99.558217
# 2014-09-03  1.090815e-13   40.227088
# 2014-09-04  2.123733e-13  -15.167423
# 2014-09-05  1.176343e-13   80.470915
# 2014-09-06 -6.005402e-13  -59.733891
# 2014-09-07  2.892172e-13 -102.783714
# 2014-09-08 -2.463215e-13  -27.392621
# 2014-09-09  1.185554e-13  109.034407
# 2014-09-10  1.090815e-13   61.738993
# 2014-09-11  2.123733e-13   16.892101
# 2014-09-12  1.176343e-13  -26.910037
# 2014-09-13 -6.005402e-13 -118.174367
# 2014-09-14  2.892172e-13 -139.176572
# 2014-09-15 -2.463215e-13   -4.118811
# 2014-09-16  1.185554e-13  190.582026
# 2014-09-17  1.090815e-13   81.227088
# 2014-09-18  2.123733e-13  -43.345994
# 2014-09-19  1.176343e-13   28.709010
# 2014-09-20 -6.005402e-13 -108.233891
# 2014-09-21  2.892172e-13  -82.426572
# 2014-09-22 -2.463215e-13   40.500236
# 2014-09-23           NaN         NaN
# 2014-09-24           NaN         NaN
# 2014-09-25           NaN         NaN
#
# [762 rows x 2 columns]

# %% [markdown]
# ### Visualize the Level, Trend, Seasonality and Residual from the dataset

# %%
import statsmodels.api as sm

# %%
sm.tsa.seasonal_decompose(daily_data.Count).plot()
result = sm.tsa.stattools.adfuller(daily_data.Count)
plt.show()

# %% [markdown]
# ### Naive Approach

# %%
naive_value = training_data.Count.iloc[-1]
naive_value
# Out:
# 372.1666666666667

# %%
naive_approach = validation_data.copy()

# %%
naive_list = [naive_value for i in range(naive_approach.shape[0])]
len(naive_list)
# Out:
# 93

# %%
naive_approach.shape[0]
# Out:
# 93

# %%
naive_approach['Naive'] = naive_list
naive_approach.head()
# Out:
#                  ID       Count       Naive
# Datetime
# 2014-06-25  16067.5  353.666667  372.166667
# 2014-06-26  16091.5  395.250000  372.166667
# 2014-06-27  16115.5  282.333333  372.166667
# 2014-06-28  16139.5  218.250000  372.166667
# 2014-06-29  16163.5  196.250000  372.166667

# %%
font_dict = {
    'family': 'serif',
    'weight': 'normal',
    'size': 20
}
plt.figure(figsize=(15, 10))
training_data.Count.plot(label = 'Training Data', linewidth=2)
validation_data.Count.plot(label = 'Validation Data', linewidth=2)
naive_approach.Naive.plot(label = 'Naive Approach', linewidth=4)
plt.legend()
plt.xlabel('Yearly Data', fontdict=font_dict)
plt.ylabel('Average Passengers Count', fontdict=font_dict)
plt.title('Passenger Prediction based on Naive Approach', fontdict=font_dict)
plt.savefig('Visualization/Prediction-Naive-Approach.png')
plt.show()

# %% [markdown]
# ### Evaluating Naive Approach

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse = sqrt(mean_squared_error(naive_approach.Naive, validation_data.Count))
print(rmse)
# Out:
# 111.79050467496724

# %% [markdown]
# ### Moving Approach

# %%
moving_approach = validation_data.copy()

# %%
moving_value = training_data.Count.rolling(30).mean().iloc[-1]
print(moving_value)
# Out:
# 321.43333333333345

# %%
moving_approach_list = [moving_value for i in range(validation_data.shape[0])]
moving_approach['Moving'] = moving_approach_list

# %%
moving_approach.Moving.head()
# Out:
# Datetime
# 2014-06-25    321.433333
# 2014-06-26    321.433333
# 2014-06-27    321.433333
# 2014-06-28    321.433333
# 2014-06-29    321.433333
# Freq: D, Name: Moving, dtype: float64

# %%
font_dict = {
    'family': 'serif',
    'size': 20
}
plt.figure(figsize=(15, 10))
training_data.Count.plot(label = 'Training Data', linewidth=2)
validation_data.Count.plot(label = 'Validation Data', linewidth=2)
moving_approach.Moving.plot(label='Moving Approach', linewidth=4)
plt.xlabel('Yearly Data', fontdict=font_dict)
plt.ylabel('Average Passenger Count', fontdict=font_dict)
plt.legend()
plt.title('Passenger Count Prediction Using Moving Approach', fontdict=font_dict)
plt.savefig('Visualization/Prediction-Moving-Approach.png')
plt.show()

# %%
rmse_moving = sqrt(mean_squared_error(validation_data.Count, moving_approach.Moving))
print("Error for moving approach is - ", rmse_moving)
# Out:
# Error for moving approach is -  129.6495809983456

# %% [markdown]
# ### Simple Exponential Approach

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, Holt
import numpy as np

# %%
ses_approach = validation_data.copy()

# %%
ses_data = SimpleExpSmoothing(np.asarray(training_data.Count)).fit(smoothing_level=0.6,optimized=False)
ses_approach['SES'] = ses_data.forecast(len(ses_approach))
ses_approach.head()
# Out:
#                  ID       Count         SES
# Datetime
# 2014-06-25  16067.5  353.666667  363.522492
# 2014-06-26  16091.5  395.250000  363.522492
# 2014-06-27  16115.5  282.333333  363.522492
# 2014-06-28  16139.5  218.250000  363.522492
# 2014-06-29  16163.5  196.250000  363.522492

# %% [markdown]
# #### Smoothing Constant or Level (aplha - α) - 0 < α < 1

# %%
font_dict = {
    'family': 'serif',
    'size': 20
}
plt.figure(figsize=(15, 10))
training_data.Count.plot(label = 'Training Data', linewidth=2)
validation_data.Count.plot(label = 'Validation Data', linewidth=2)
ses_approach.SES.plot(label = 'Simple Exponential Smoothing Approach', linewidth=4)
plt.legend()
plt.xlabel('Yearly Data', fontdict = font_dict)
plt.ylabel('Average Passenger Count', fontdict = font_dict)
plt.title('Prediction using Simple Exponential Smoothing', fontdict = font_dict)
plt.savefig('Visualization/Prediction-Simple-Exponential-Smoothing.png')
plt.show()

# %%
rmse_ses_approach = sqrt(mean_squared_error(validation_data.Count, ses_approach.SES))
print("Simple Exponential Error is - ", rmse_ses_approach)
# Out:
# Simple Exponential Error is -  113.43708111884514

# %% [markdown]
# ### Holtz's Linear Trend Model

# %% [raw]
# Components of Holtz's Linear Trend Model
# 1. Uses ideas from Exponential Smoothing.
# 2. Trend of the data.
# 3. Weightage increases, with increase in the recent data.

# %%
from IPython.display import Image
Image("Formula-Holts-Linear.png")

# %%
holt_approach = validation_data.copy()
holt_data = Holt(np.asarray(training_data.Count)).fit(smoothing_level = 0.3,smoothing_slope = 0.1)
holt_approach['Holt'] = holt_data.forecast(len(validation_data))

# %%
holt_approach.Holt.head()
# Out:
# Datetime
# 2014-06-25    334.650767
# 2014-06-26    337.159011
# 2014-06-27    339.667256
# 2014-06-28    342.175500
# 2014-06-29    344.683745
# Freq: D, Name: Holt, dtype: float64

# %%
font_dict = {
    'family': 'serif',
    'size': 20
}
plt.figure(figsize=(15, 10))
training_data.Count.plot(label='Training Data', linewidth=2)
validation_data.Count.plot(label='Validation Data', linewidth=2)
holt_approach.Holt.plot(label="Holt's Linear Trend Model", linewidth=3)
plt.xlabel('Yearly Data', fontdict=font_dict)
plt.ylabel('Average Passengers Count', fontdict=font_dict)
plt.legend()
plt.title("Prediction using Holt's Linear Trend Model", fontdict=font_dict)
plt.savefig('Visualization/Prediction-Holt-Linear-Trend-Model.png')
plt.show()

# %%
rmse_holt_approach = sqrt(mean_squared_error(validation_data.Count, holt_approach.Holt))
print("Error in holt approach is - ", rmse_holt_approach)
# Out:
# Error in holt approach is -  112.94278345314041

# %% [markdown]
# ### Holt's Winter Model (For seasonality)

# %% [raw]
# Three Components of Holt's Winter Model -
# 1. Uses ideas from Exponential Smoothing.
# 2. Level.
# 3. Trend (Weight increase, with increase in the recent data).
# 4. Seasonality.

# %% [markdown]
# #### Formula - Level, Trend, Seasonality

# %%
from IPython.display import Image
Image("Holts-Winter-Level.png")

# %%
from IPython.display import Image
Image("Holts-Winter-Trend.png")

# %%
from IPython.display import Image
Image("Holts-Winter-Seasonality.png")

# %% [markdown]
# ### Calculating Seasonal index

# %%
from statsmodels.tsa.api import ExponentialSmoothing

# %%
holt_winter_approach = validation_data.copy()

# %%
holt_winter_data = ExponentialSmoothing(np.asarray(training_data.Count), seasonal_periods=7, trend='add', seasonal='add').fit()
holt_winter_data_list = holt_winter_data.forecast(len(validation_data))
holt_winter_approach['Winter_Data'] = holt_winter_data_list
holt_winter_approach.Winter_Data.head()
# Out:
# Datetime
# 2014-06-25    387.359560
# 2014-06-26    369.135738
# 2014-06-27    355.562024
# 2014-06-28    247.089851
# 2014-06-29    246.193399
# Freq: D, Name: Winter_Data, dtype: float64

# %%
font_dict = {
    'family': 'serif',
    'size': 20
}
plt.figure(figsize=(15, 10))
training_data.Count.plot(label='Training Data', linewidth=2)
validation_data.Count.plot(label='Validation Data', linewidth=2)
holt_winter_approach.Winter_Data.plot(label="Holt's Winter Model", linewidth=2)
plt.xlabel('Yearly Data', fontdict = font_dict)
plt.ylabel('Average Passenger Count', fontdict = font_dict)
plt.title("Prediction using Holt's Winter Model", fontdict = font_dict)
plt.savefig('Visualization/Prediction-using-Holt-Winter-Model.png')
plt.show()

# %%
rmse_holt_winter_approach = sqrt(mean_squared_error(validation_data.Count, holt_winter_approach.Winter_Data))
print("Error in holt winter approach is - ", rmse_holt_winter_approach)
# Out:
# Error in holt winter approach is -  82.37900996094073

# %% [markdown]
# ## ARIMA Model

# %% [markdown]
# ## Check if the Data is stationary or not?

# %% [raw]
# 1. We use Dickey Fuller test to check the stationarity of the series.
# 2. The intuition behind this test is that it determines how strongly a time series is defined by a trend.
# 3. The null hypothesis of the test is that time series is not stationary (has some time-dependent structure).
# 4. The alternate hypothesis (rejecting the null hypothesis) is that the time series is stationary.

# %%
rolling_mean = data['Count'].rolling(24).mean()
rolling_std = data['Count'].rolling(24).std()

# %%
font_dict = {
    'family': 'serif',
    'size': 20
}
plt.figure(figsize=(15,8))
plt.plot(data['Count'], label='Original Data')
plt.plot(rolling_mean, label='Rolling Mean')
plt.plot(rolling_std, label='Rolling Standard Deviation')
plt.legend()
plt.xlabel('Date', fontdict = font_dict)
plt.ylabel('Passenger Count', fontdict = font_dict)
plt.title('Increase in Passenger over years', fontdict = font_dict)
plt.show()

# %%
def differencingMethod(dataset, differencing_value = 1):
    ## diffencing the data
    differenced = dataset - dataset.shift(differencing_value)
#     return differenced

    ## checking mean and standard deviation
    rolling_mean = differenced.rolling(12).mean()
    rolling_std = differenced.rolling(12).std()
    
    ## visualize the data to see if the mean, variance revolves around 0 or not.
    difference_label = 'Differenced Data-'+str(differencing_value)
    plt.figure(figsize=(18, 8))
    plt.plot(differenced, label = difference_label)
    plt.plot(rolling_mean, label = 'Mean')
    plt.plot(rolling_std, label = 'Variance')
    plt.xlabel('Date')
    plt.ylabel('Count of Passengers')
    plt.legend()
    
    ## printing mean, standard deviation
    print('Rolling Mean is:', np.mean(rolling_mean))
    print('Rolling Standard Deviation is:', np.mean(rolling_std))

# %%
import seaborn as sns
sns.set()

# %%
differencingMethod(dataset=data['Count'])
# Out:
# Rolling Mean is: 0.03623148756110015
# Rolling Standard Deviation is: 30.785121034962486

# %%
differencingMethod(dataset=data['Count'], differencing_value=2)
# Out:
# Rolling Mean is: 0.07304149566803467
# Rolling Standard Deviation is: 40.6209500691928

# %% [markdown]
# ### Observations -
# Taking differencing value as 1.

# %% [markdown]
# ## Plotting ACF and PACF graph for the differencing data.

# %%
from statsmodels.tsa.stattools import acf, pacf

# %%
differenced_data = data['Count'] - data['Count'].shift(1)

# %%
differenced_data.dropna(inplace=True)

# %%
lag_acf = pd.Series(acf(differenced_data, nlags=10))
lag_pacf = pd.Series(pacf(differenced_data, nlags=10, method='ols'))

# %%
plt.figure(figsize=(13, 5))
lag_acf.plot.bar()
lag_acf.plot()

# %%
plt.figure(figsize=(13, 5))
lag_pacf.plot.bar()
lag_pacf.plot()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
training_data.shape[0]
# Out:
# 669

# %%
validation_data.shape[0]
# Out:
# 93

# %%
history = []

# %%
history = [value for value in training_data['Count']]
predictions = []

# %%
len(history)
# Out:
# 669

# %%
training_data.shape[0]
# Out:
# 669

# %%
for i in range(validation_data.shape[0]):
#     if (i==7):
#         break
    arima_model = ARIMA(history, order=(5, 1, 1))
    arima_model_fit = arima_model.fit(disp=-1)
    output = arima_model_fit.forecast()[0][0]
    predictions.append(output)
    actual_value = validation_data['Count'].iloc[i]
    history.append(actual_value)

# %% [markdown]
# ## Visualizing the predictions made

# %%
observed_values = pd.Series(history, index=daily_data.index)

# %%
observed_values.head()
# Out:
# Datetime
# 2012-08-25    3.166667
# 2012-08-26    3.666667
# 2012-08-27    2.583333
# 2012-08-28    2.416667
# 2012-08-29    2.500000
# Freq: D, dtype: float64

# %%
predicted_values = pd.Series(predictions, index=validation_data.index)

# %%
predicted_values.head()
# Out:
# Datetime
# 2014-06-25    284.485773
# 2014-06-26    369.001654
# 2014-06-27    343.799180
# 2014-06-28    217.424992
# 2014-06-29    300.430382
# Freq: D, dtype: float64

# %%
plt.figure(figsize=(15, 7))
plt.plot(observed_values, label='Original Data')
plt.plot(predicted_values, label='Predicted Values')
plt.legend()

# %% [markdown]
# ## Checking error

# %%
arima_error = sqrt(mean_squared_error(validation_data['Count'], predicted_values.values))

# %%
arima_error
# Out:
# 74.01902054066397

# %% [markdown]
# ## Making predictions of test dataset

# %%
test_data = pd.read_csv('data/Test.csv')

# %%
test_data.head()
# Out:
#       ID          Datetime
# 0  18288  26-09-2014 00:00
# 1  18289  26-09-2014 01:00
# 2  18290  26-09-2014 02:00
# 3  18291  26-09-2014 03:00
# 4  18292  26-09-2014 04:00

# %%
test_data.Datetime = pd.to_datetime(test_data.Datetime, infer_datetime_format=True)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5112 entries, 0 to 5111
# Data columns (total 2 columns):
# ID          5112 non-null int64
# Datetime    5112 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 80.0 KB

# %% [markdown]
# ## Making ARIMA model for hourly data

# %%
data.shape[0]
# Out:
# 18288

# %%
size = int((data.shape[0]*0.7))
size
# Out:
# 12801

# %%
hourly_training = data['Count'][:size]
hourly_test = data['Count'][size:]

# %%
hourly_training.head()
# Out:
# Datetime
# 2012-08-25 00:00:00    8
# 2012-08-25 01:00:00    2
# 2012-08-25 02:00:00    6
# 2012-08-25 03:00:00    2
# 2012-08-25 04:00:00    2
# Name: Count, dtype: int64

# %%
hourly_history = []
hourly_history = [value for value in hourly_training]
hourly_predictions = []

# %%
for i in range(hourly_test.shape[0]):
#     if (i==7):
#         break
    arima_model = ARIMA(hourly_history, order=(2, 1, 0))
    arima_model_fit = arima_model.fit(disp=-1)
    output = arima_model_fit.forecast()[0][0]
    hourly_predictions.append(output)
    actual_value = hourly_test.iloc[i]
    hourly_history.append(actual_value)
# Out:
# c:\users\jatinder\appdata\local\programs\python\python36\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# c:\users\jatinder\appdata\local\programs\python\python36\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# c:\users\jatinder\appdata\local\programs\python\python36\lib\site-packages\scipy\signal\signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]

# %%
len(hourly_test)
# Out:
# 5487

# %%
len(hourly_predictions)
# Out:
# 5487

# %%
hourly_predictions
# Out:
# [172.89394619247722,
#  206.6655435268015,
#  198.33618810400083,
#  181.86394269871872,
#  186.89835290217007,
#  182.82124141294352,
#  180.2139721700324,
#  179.99891127534255,
#  167.7444021811085,
#  129.08598272973904,
#  165.73944354754724,
#  188.16678954793915,
#  205.93635320230987,
#  222.18653187057635,
#  274.9971843094549,
#  268.4697504209568,
#  246.60892184257202,
#  229.81725336421553,
#  215.61605150650834,
#  178.83109946421436,
#  199.99177313257823,
#  183.22333421071625,
#  248.1749436967064,
#  223.6371665605793,
#  240.44982563069212,
#  321.3511956448593,
#  364.33935478755757,
#  387.64051725598915,
#  391.9803041308394,
#  385.0349543550196,
#  389.2246922036019,
#  369.0381699836913,
#  362.3125395969773,
#  325.15929370947686,
#  335.4394499906452,
#  325.9122883215633,
#  313.3789040882263,
#  317.1813974916862,
#  330.35807446271536,
#  307.59812028722064,
#  226.58463253344007,
#  176.6003549626138,
#  168.10193926697409,
#  139.88254360818743,
#  149.76084407370843,
#  125.82683972300927,
#  88.36659074515858,
#  113.50452435529606,
#  123.58760723210264,
#  185.5250022587514,
#  249.15875037635848,
#  268.93005802194887,
#  266.6441165859662,
#  273.0134636948285,
#  303.9800848015029,
#  313.6308629382736,
#  264.8725468996426,
#  252.21517000972756,
#  262.51063481659463,
#  299.291053617259,
#  269.2507363214816,
#  274.1915106039007,
#  300.73794653927877,
#  284.9529581622605,
#  215.0361258835917,
#  178.9494658660101,
#  144.07191813772747,
#  141.428565278312,
#  106.85435931548062,
#  101.62151845576544,
#  79.1424347695634,
#  114.44197401418303,
#  139.78508072698187,
#  217.89576766637734,
#  227.14063390602215,
#  271.7521389901232,
#  271.5449599817031,
#  229.46336247131217,
#  274.55701199045524,
#  287.9010102270224,
#  281.0485057441553,
#  279.94133813546114,
#  297.61688264034666,
#  289.67454457620437,
#  257.9927870563352,
#  258.95366597210136,
#  270.6386672161693,
#  256.3101949456459,
#  186.97525063285167,
#  203.64818021287448,
#  174.9022564285496,
#  181.93692436938733,
#  119.08742452310172,
#  116.26118050234697,
#  126.8875080198197,
#  110.52719307932703,
#  118.35183272732561,
#  153.55186806761088,
#  202.3952102412865,
#  233.18785454570002,
#  262.7255266831337,
#  266.34905893007937,
#  285.3836138305841,
#  291.78591885034956,
#  255.10599105718836,
#  260.1248768327651,
#  277.99150630564037,
#  267.89679581123755,
#  269.3917891985897,
#  273.58557834084326,
#  235.34693126167346,
#  238.34734882430325,
#  203.17237453208898,
#  208.1161114626556,
#  153.84254744729873,
#  157.60961745484735,
#  119.70621943841527,
#  102.91937660853891,
#  96.58974956725906,
#  81.85973295378378,
#  123.81034097507053,
#  216.86207596129853,
#  336.8550618375907,
#  344.5001966373008,
#  334.8722755431809,
#  307.46258929253565,
#  365.39269782293616,
#  336.1064527233124,
#  262.47660916960734,
#  240.76506353919888,
#  289.25762960124575,
#  280.7863728746014,
#  304.27428682462204,
#  276.6272373995114,
#  248.67590746698932,
#  272.18069557158054,
#  218.1789511384283,
#  170.45149434493115,
#  142.559983850922,
#  139.70695863383975,
#  92.36694915187502,
#  103.01022622840493,
#  88.60418469906247,
#  84.00301696497495,
#  106.91961520225557,
#  103.2607654869809,
#  114.2628766899058,
#  156.7586675323822,
#  146.68035259469988,
#  152.61883909823013,
#  148.83885885525171,
#  140.88325912271858,
#  131.0943778328503,
#  152.82689459218386,
#  149.26504009320172,
#  149.68106913966122,
#  146.50747415319668,
#  128.32180653828573,
#  141.64991224705886,
#  144.22542091767943,
#  136.95499248297295,
#  104.15962145482882,
#  87.22903764567398,
#  96.42711007125632,
#  91.09264872878845,
#  59.91789750239109,
#  52.07337126910725,
#  64.30790267270314,
#  74.99198054589507,
#  88.47537812040822,
#  121.93659723775748,
#  119.37744521404056,
#  124.97306663445767,
#  120.81114301193998,
#  109.35081182727761,
#  118.45409770192968,
#  113.09348835870601,
#  117.2077879523333,
#  121.60965140445428,
#  162.64370044166665,
#  157.9728285265378,
#  180.57153049917474,
#  187.8804926673979,
#  196.88646981504215,
#  171.6690742194478,
#  120.00181264491515,
#  150.42300068081673,
#  117.70937027102084,
#  72.6684587304492,
#  51.5953117969057,
#  65.67236102551051,
#  99.98513149556888,
#  111.49413927283427,
#  180.94957538976823,
#  281.11813644233337,
#  318.0914410844639,
#  364.6266122777073,
#  351.2471551287843,
#  340.65986933333653,
#  336.3836873296317,
#  357.1987766670124,
#  374.5009141807814,
#  323.18597238796593,
#  339.9898320952717,
#  346.1650899860264,
#  331.9089289683678,
#  266.15050733946015,
#  269.4584154028357,
#  236.84242873541265,
#  243.86072181612033,
#  186.09520673570918,
#  168.24051666081806,
#  141.3455393342606,
#  105.75091005436967,
#  106.81023873226249,
#  129.31817112330475,
#  142.95825468558363,
#  181.33120425199525,
#  222.00030488825058,
#  233.66556263153439,
#  283.691277629107,
#  225.37778964536557,
#  335.0488581243279,
#  297.63188413158355,
#  257.0590791060037,
#  253.5186915923378,
#  321.1250055994175,
#  368.2337057878041,
#  344.36514509386683,
#  284.8080216589594,
#  270.0861106180765,
#  246.93451643350613,
#  204.7631835123222,
#  162.25148952761603,
#  143.25493982173586,
#  127.62987950213571,
#  132.84935393718044,
#  95.22582223699382,
#  107.04090875410395,
#  99.69520533611434,
#  104.90277318251329,
#  219.29658242572313,
#  297.9004095577562,
#  342.32812489730554,
#  325.41719221794995,
#  280.9084494679922,
#  296.58597978549176,
#  330.50429606609697,
#  277.84777650073613,
#  348.71668958704674,
#  280.0747861322194,
#  326.63818100309527,
#  268.2722234246904,
#  251.4242166850462,
#  264.2887991783321,
#  227.38802826104651,
#  178.88316123307038,
#  173.22293402832264,
#  143.97112433521247,
#  130.6074265389201,
#  87.42134171286355,
#  59.97915589702999,
#  84.11665397335341,
#  92.0445796816173,
#  92.07406252201415,
#  185.69644189009762,
#  199.79857165924383,
#  229.84229600115845,
#  241.71303967789243,
#  233.3163968697975,
#  253.06444422118093,
#  254.66618622738832,
#  278.74041287368095,
#  309.03349588559644,
#  254.19765225057563,
#  289.0675759291249,
#  265.08832604242946,
#  195.77933383409652,
#  236.27769138375555,
#  183.1748030592426,
#  155.15753335076573,
#  141.30359218661607,
#  106.20322512892935,
#  71.30960586651388,
#  62.11226151596608,
#  74.26999924291262,
#  69.18041141689577,
#  67.86632424193247,
#  80.3743919404576,
#  137.03367700334616,
#  231.77546755351065,
#  243.7537841082575,
#  252.634360651065,
#  240.08187660650702,
#  262.4995782550835,
#  257.6769392168784,
#  250.53573543572284,
#  196.84134539593592,
#  194.2481902506025,
#  233.27151506125233,
#  180.39678893825212,
#  199.14070701017508,
#  209.8820501515043,
#  188.9044253836589,
#  166.14600573270403,
#  121.18131861325924,
#  109.85695030583175,
#  90.44605846332539,
#  61.08199888032155,
#  57.470357453134625,
#  54.46634791375112,
#  52.16368736612988,
#  69.6573197510189,
#  116.59046621462471,
#  110.5149265843513,
#  134.29243217941809,
#  120.86051806259772,
#  121.18795250717021,
#  150.38358034816522,
#  97.99253530862096,
#  129.52096047811722,
#  124.46329574074925,
#  151.80761112922755,
#  124.81531343028715,
#  138.79393325707483,
#  158.31830251404796,
#  174.4812275819037,
#  148.02534337880067,
#  118.68494596740054,
#  127.8768751759342,
#  75.47510177787015,
#  58.036868888894745,
#  64.89323226853237,
#  44.93908202772835,
#  48.6367153724453,
#  46.613995399688896,
#  72.44378830475625,
#  101.3013022012463,
#  122.20032082412315,
#  122.60792213161494,
#  132.5806381469005,
#  113.01602918357729,
#  134.31636973194475,
#  133.22206886098695,
#  147.80951205519614,
#  132.66714064012092,
#  111.96493932322169,
#  136.1562975851288,
#  181.22005001680873,
#  142.65936089973948,
#  189.86759248099906,
#  179.7213614240687,
#  179.14336089831508,
#  155.35532938494825,
#  133.82825176864478,
#  128.10776229733696,
#  94.36546548095077,
#  82.23385247387421,
#  90.69293979354111,
#  111.62910870101055,
#  112.64874674066073,
#  219.75935701402682,
#  259.30621970700497,
#  264.0496218208646,
#  327.75800524690976,
#  286.1440238492347,
#  338.7255650458392,
#  310.55348627882,
#  281.96753260205344,
#  272.4865552565798,
#  278.9318837030796,
#  333.17867310827336,
#  312.9344535932992,
#  291.5092123555426,
#  289.6758358300176,
#  263.5266301410731,
#  220.56964470782268,
#  206.3263540176571,
#  170.47778655386946,
#  136.9445984534362,
#  129.84283975824675,
#  119.32573166247495,
#  100.09532345870713,
#  104.68146935038169,
#  136.21555341766964,
#  138.91467806755222,
#  201.60655650245897,
#  255.67765708081723,
#  250.40968435556513,
#  228.32748360858167,
#  276.8629644928912,
#  294.01011546656764,
#  304.83319279996465,
#  262.05226455660176,
#  246.19076444345663,
#  244.05372150517587,
#  364.23650079115737,
#  282.0474448178609,
#  314.9064523166562,
#  265.26075624666873,
#  231.68681630713724,
#  142.97263586057082,
#  124.61139058018529,
#  117.05289766764788,
#  135.21395816314268,
#  108.47457391197615,
#  105.04045360736139,
#  123.70462474194468,
#  147.62524147867904,
#  325.44252053690934,
#  471.4130880985503,
#  460.2215769854152,
#  410.86770799464756,
#  342.877995864292,
#  334.4891869887729,
#  327.1547104126581,
#  306.28588911801785,
#  370.9596668223232,
#  346.22894725697876,
#  319.64520731358965,
#  310.45050640963086,
#  350.6485161177858,
#  318.0122874583173,
#  295.11329968804785,
#  279.4441322352782,
#  210.2605572906419,
#  191.48014317239048,
#  188.24719029096133,
#  118.72365861776828,
#  90.5377093598389,
#  94.89128973942857,
#  122.7632053534535,
#  178.15611720005603,
#  219.04587356385858,
#  274.39972341844987,
#  316.89399355579576,
#  338.72209209163276,
#  240.97123311110607,
#  298.27397531376226,
#  320.73081090624737,
#  247.46019510300343,
#  287.70780332913154,
#  268.8998152654261,
#  277.5153060768956,
#  291.01401305761584,
#  226.65469625336294,
#  248.33760941388823,
#  228.2081832545054,
#  226.9102211801036,
#  173.1396053014946,
#  114.97552570821479,
#  133.61650263412469,
#  94.29394091552953,
#  86.90148230331602,
#  107.51505043990066,
#  121.13326499134465,
#  147.10520626396146,
#  203.85439754117618,
#  245.07635539645594,
#  266.6244251002862,
#  291.550313776778,
#  246.68991914500037,
#  268.9665690439028,
#  276.5619147443058,
#  268.96904440199387,
#  228.8013679040103,
#  262.0626972386601,
#  281.4244136138979,
#  241.5268326722388,
#  224.35720309252838,
#  211.33127626666874,
#  188.4124489402101,
#  213.87186676599984,
#  190.3422811609155,
#  135.62471046451057,
#  102.14418543027922,
#  79.8108773798943,
#  63.31093544220489,
#  52.769176535368764,
#  81.95903059261444,
#  77.8909363058901,
#  88.20779213138627,
#  129.3766035759187,
#  119.01680373691998,
#  124.48201761590312,
#  122.68321016160722,
#  118.36968538882887,
#  125.02017485780014,
#  117.31306740291085,
#  138.86096727454313,
#  115.96994891657137,
#  146.82746753082432,
#  136.94214536923377,
#  153.12307185948032,
#  170.70609708400755,
#  142.20732220219676,
#  131.92250533931235,
#  91.05707169908445,
#  86.73834194174712,
#  54.33267407818426,
#  43.810224611543426,
#  42.09099379600551,
#  52.605974830345886,
#  66.70210840981062,
#  63.000530320283396,
#  97.36284840618909,
#  118.8990859840941,
#  131.07308637312528,
#  139.38646892610006,
#  99.36946326849335,
#  107.15141953018058,
#  113.92457784599152,
#  126.52487101336807,
#  154.95638842384835,
#  144.5003868630382,
#  152.29334939510647,
#  143.6383399576502,
#  150.6096681045043,
#  146.9169724210748,
#  147.64828909339016,
#  137.4084066490418,
#  103.78577050788846,
#  99.1798929139988,
#  84.0326385339082,
#  79.81594203561411,
#  90.60987917133701,
#  85.1835823154388,
#  113.99542900717643,
#  92.17316601965743,
#  197.29112211987018,
#  303.7636750029683,
#  328.61428691478176,
#  285.736561433711,
#  323.33561272938516,
#  324.07694150890705,
#  305.84812214382737,
#  344.47696182126765,
#  294.2505601617262,
#  316.5026565761661,
#  340.61571399953453,
#  374.4639100489734,
#  291.86039501464023,
#  284.87637933122903,
#  261.5757990905417,
#  246.6698525194433,
#  215.55149973826366,
#  159.7080891502354,
#  122.43537148328708,
#  120.98219065151211,
#  86.52056660736977,
#  111.2562849258761,
#  84.84747930669923,
#  130.6417203353689,
#  157.1653929308091,
#  218.90956599361124,
#  241.90267859566902,
#  290.40714719080455,
#  299.14972153660625,
#  356.7342670710612,
#  335.489710436176,
#  323.83549768835775,
#  314.98757125354217,
#  313.77186526113076,
#  317.5794371983927,
#  316.3491075119239,
#  280.4289256697615,
#  306.9974284969862,
#  314.71007985493065,
#  237.66686046251644,
#  234.76307964839583,
#  177.8584715788685,
#  177.16404421795622,
#  132.29756753199038,
#  83.73139070745644,
#  89.48338020973198,
#  108.31201185195779,
#  124.69133261227265,
#  261.5631235352241,
#  378.30305191123324,
#  431.82031117540953,
#  349.73125125941385,
#  349.75483244329456,
#  315.24075523496714,
#  285.6701410681708,
#  244.09092902413676,
#  274.4919440431487,
#  382.7477255109359,
#  423.8345021219149,
#  360.57499784853763,
#  305.5656520655929,
#  318.6033085936908,
#  290.4117689638101,
#  245.83470703732746,
#  242.68357527203477,
#  249.4251921607871,
#  173.41873049208178,
#  133.25450369415543,
#  109.75694691334594,
#  118.10846763513793,
#  120.31656035318463,
#  166.44325536971556,
#  180.494218651945,
#  215.94556214212102,
#  249.6411871768141,
#  242.13105238505338,
#  257.57092907814945,
#  255.1812499957384,
#  286.01818703112144,
#  274.8853097392167,
#  294.77089874247037,
#  296.9176212316406,
#  315.61915175063774,
#  300.7408078887012,
#  293.9269482358885,
#  299.2767029543799,
#  259.10099436524035,
#  236.73722055847253,
#  194.4514098307275,
#  197.73065763911933,
#  119.89638368080557,
#  107.58890931478103,
#  88.56857039977699,
#  79.99586653017364,
#  92.35013349720133,
#  144.41661319961398,
#  183.7028990746176,
#  233.48821472838932,
#  275.22656908257807,
#  279.12998056870623,
#  274.44483176787156,
#  323.98555597882466,
#  281.51774718581174,
#  256.38729221524176,
#  275.19426387267504,
#  242.87027912980358,
#  199.37256597840363,
#  244.9302268623303,
#  228.51873232662953,
#  287.57935682351155,
#  262.2824076714894,
#  215.61624511458396,
#  191.1512526036954,
#  119.6834051844744,
#  77.63574510180348,
#  98.25382791810371,
#  61.60852814718453,
#  67.23562736421155,
#  82.9103387735846,
#  104.06477078844907,
#  74.4380696673612,
#  117.26294992754984,
#  138.02647053444792,
#  118.7343624285263,
#  111.82414426607653,
#  136.92463179217037,
#  130.05868613591477,
#  129.46580042651715,
#  133.64019521966216,
#  135.90814753332316,
#  168.24216611192273,
#  169.4328344942427,
#  160.7521555541393,
#  131.1889472866453,
#  155.72617790436018,
#  123.36726210177672,
#  95.39977649649772,
#  93.34417598285137,
#  86.85707135323725,
#  51.82216044721029,
#  64.82778058071071,
#  52.472255876764166,
#  69.1645827459884,
#  76.18924584206738,
#  92.20249957190694,
#  101.65592510164338,
#  171.94505467414487,
#  146.44714694827084,
#  140.6848427310803,
#  145.64037774376294,
#  133.61323417208416,
#  117.32450566887559,
#  106.62824185215632,
#  148.61816969109387,
#  175.00143056966007,
#  189.13627065785124,
#  185.04147098879648,
#  173.12352976573362,
#  185.97871838295023,
#  195.60752968816846,
#  169.42742428372145,
#  129.43207168628862,
#  112.38657775536474,
#  81.22457973277967,
#  62.752431662075985,
#  77.65021253515607,
#  69.77994636113073,
#  123.08975492806427,
#  224.7804466997908,
#  281.7367991653165,
#  324.87729299273207,
#  366.93797236767364,
#  353.33580563800234,
#  379.8977389973847,
#  327.71356966796435,
#  359.3219459941553,
#  340.5355121437755,
#  293.95958429698896,
#  362.06685861757023,
#  306.46546071037955,
#  266.97712971074105,
#  336.71570703019944,
#  285.73935942972594,
#  254.37618541277973,
#  233.72426561989502,
#  158.0537462414322,
#  142.2925859571559,
#  111.63479030748374,
#  98.01810833636479,
#  94.13866958086614,
#  77.78840581802172,
#  107.68522979216534,
#  190.00434988014462,
#  247.08682190027872,
#  274.8376675029128,
#  251.7086328703484,
#  223.9147760953713,
#  255.28887323428967,
#  282.61828397186525,
#  272.1798190465671,
#  240.95673719981295,
#  255.00527037559635,
#  360.70586163962366,
#  484.8172609244836,
#  325.4671851194596,
#  263.0282308537949,
#  261.248302545706,
#  229.71253658799586,
#  208.95352354353514,
#  177.0766812578034,
#  117.54319852387516,
#  104.99882537677338,
#  89.71201255800075,
#  100.08216371620505,
#  122.10017261562847,
#  142.52172710103378,
#  236.02097396086694,
#  414.2212203698833,
#  438.7037986839064,
#  410.75884102342854,
#  369.5534476788584,
#  323.5032831541269,
#  342.17158789590934,
#  348.5273416885159,
#  306.70053447414904,
#  286.3933148364172,
#  294.5897207695397,
#  321.4813532104588,
#  308.5803902993882,
#  350.5175115815197,
#  292.63267080929796,
#  247.9134719160807,
#  286.38510717714655,
#  233.9087085562336,
#  161.31315701476328,
#  145.16700127579614,
#  122.3518713123936,
#  108.51968494092479,
#  120.28575320825766,
#  149.37464277448936,
#  163.60641722447454,
#  225.53110861276775,
#  277.06431532159576,
#  286.71840637769833,
#  347.4193980923942,
#  341.47727064779815,
#  332.18768679920504,
#  292.24113214064994,
#  243.5833248431134,
#  265.7280993625123,
#  274.4390042247985,
#  266.92504231118494,
#  291.0187670637042,
#  291.1813834420002,
#  264.6981595832266,
#  232.43937644940698,
#  193.112187210588,
#  194.32938251194636,
#  170.95651775009446,
#  116.79225359124939,
#  101.4634733287376,
#  96.32671109198715,
#  108.45756270994355,
#  141.02973343406595,
#  184.6022579913552,
#  281.22908212744085,
#  287.4597740452852,
#  265.81869503590264,
#  268.87785247005195,
#  225.0962354697693,
#  296.14789851411484,
#  274.17935107228766,
#  247.14208569640823,
#  247.21287755530594,
#  244.46927162040518,
#  288.96899509891387,
#  225.14039830148502,
#  235.47092417528523,
#  201.06257275551937,
#  192.98018208897773,
#  188.55445657992948,
#  108.57992349785836,
#  115.55081276932326,
#  79.15042728235255,
#  79.90148062973637,
#  53.41636085421605,
#  76.10262497610712,
#  91.6685673289559,
#  74.33859185934195,
#  121.85591207400557,
#  129.60732051225133,
#  115.40365693323211,
#  115.41103933114243,
#  101.65898764775295,
#  153.57066439373796,
#  123.91821122235972,
#  127.61097461137099,
#  119.5519254111401,
#  164.46536495793066,
#  158.90278067012616,
#  126.81366089579677,
#  139.29845868744874,
#  164.12033082978235,
#  148.69315961736294,
#  93.24515804514215,
#  70.16584062048447,
#  85.70157037723466,
#  61.510320531114246,
#  55.35916596543426,
#  46.946173054077974,
#  52.92214287044379,
#  66.8307271977102,
#  100.80616165695307,
#  110.42483971114872,
#  140.78686815444325,
#  132.3712789779803,
#  131.41332007182942,
#  114.0622746339487,
#  131.24465384733125,
#  125.63270147733083,
#  147.12843203051798,
#  193.96237545228797,
#  174.1701587255784,
#  185.41998562969394,
#  163.32446203132898,
#  159.21547625430802,
#  165.41240791706906,
#  203.98733088789305,
#  131.8290764327183,
#  121.37367617067952,
#  91.67270073965383,
#  74.37762644020894,
#  62.8048502254852,
#  72.45931023221164,
#  112.1461938147012,
#  117.20997519758716,
#  161.00788623068883,
#  282.7451800931849,
#  317.5745547329707,
#  300.43933642118367,
#  322.7316129136895,
#  290.7983128373059,
#  288.4673074073867,
#  297.3453109977213,
#  246.00230433460544,
#  249.1528365007845,
#  259.57192156724494,
#  251.24164936287025,
#  271.35060645734404,
#  256.6973677623044,
#  244.43489376765717,
#  249.1353305431987,
#  228.57287451225156,
#  192.89370025357746,
#  181.7685009972005,
#  125.9185794011626,
#  105.5879690954027,
#  98.39015101471576,
#  112.19220644529818,
#  143.31243125954023,
#  145.14015805505593,
#  174.5930581008648,
#  218.6675117041235,
#  270.1983232068472,
#  262.92764606346856,
#  290.25859632801837,
#  287.8155487813284,
#  246.11771261825618,
#  296.6074017168766,
#  314.85179954720127,
#  305.3021352228693,
#  215.3880072645101,
#  203.16134055380064,
#  220.44030766771118,
#  233.29855692975056,
#  194.6975575805378,
#  147.26650411325457,
#  101.18175408477673,
#  94.86474870799466,
#  72.49541568987706,
#  65.63698717257554,
#  62.2794085101732,
#  79.92848511252328,
#  84.39420938852757,
#  199.53560027500845,
#  306.1748754110404,
#  356.6591482766773,
#  303.3552452608402,
#  221.84849164929548,
#  222.7115145386136,
#  271.52490407638345,
#  232.25642664755918,
#  186.6029215082265,
#  276.83768808533114,
#  262.02904333748313,
#  229.82683017917168,
#  209.16173431047937,
#  238.18735018767802,
#  205.01281319338364,
#  157.27941184748693,
#  125.61336276541093,
#  128.59939907052504,
#  94.0192750923375,
#  79.8505700973105,
#  47.179306889144264,
#  53.841736640233364,
#  70.80396841758268,
#  85.10973093894206,
#  124.37250694269933,
#  120.14678638830826,
#  130.3848664275657,
#  181.22764372177238,
#  122.44945288675689,
#  164.37989452354677,
#  130.30758854795155,
#  138.8978727859766,
#  135.29854433991778,
#  131.9752677082527,
#  159.04764870063468,
#  148.41699305410694,
#  163.615929943733,
#  162.97096692905208,
#  145.6421844021465,
#  130.85338635175842,
#  109.7398823017645,
#  62.2128313688716,
#  72.83098763187976,
#  47.62147868980266,
#  41.276382497576805,
#  56.39631517856452,
#  63.882287229302364,
#  85.85411021057294,
#  123.02305101755063,
#  188.55629747768174,
#  219.49488179982077,
#  233.43101298580794,
#  212.73336877411575,
#  225.58421250820146,
#  181.54969014053276,
#  201.59652018677255,
#  161.72722571106485,
#  170.79390245544144,
#  143.8327767574317,
#  157.06501878778315,
#  207.5823284714515,
#  264.17415553420636,
#  211.8484901207074,
#  193.10537353562623,
#  159.38348165822765,
#  111.50493241184355,
#  74.03431470289155,
#  67.31529613910247,
#  85.96564890182077,
#  65.09866770384656,
#  86.53830240880082,
#  105.30231285627693,
#  124.56415274021903,
#  170.00341094713627,
#  166.40698542897684,
#  161.90529147139165,
#  127.59754376428597,
#  130.10509945658376,
#  139.4810184430553,
#  129.40058774703812,
#  133.07527089165396,
#  175.77550033924825,
#  165.1117512845194,
#  139.78112971688248,
#  142.72249572001988,
#  131.53242139653435,
#  115.12918728153488,
#  ...]

# %%
hourly_prediction_series = pd.Series(hourly_predictions, index=hourly_test.index)

# %%
plt.figure(figsize=(15, 8))
plt.plot(hourly_training, label='Original Data')
plt.plot(hourly_prediction_series, label='Predictions Data')
plt.xlabel('Date')
plt.ylabel('Customer Count')
plt.legend()

# %% [markdown]
# ## Computing error

# %%
arima_error = sqrt(mean_squared_error(hourly_test, hourly_prediction_series))
arima_error
# Out:
# 64.33729982610868

# %% [markdown]
# ### ARIMA Forecasting

# %%
len(test_data)
# Out:
# 5112

# %%
forecasted_values = arima_model_fit.forecast(steps=5112)[0]

# %%
forecasted_values
# Out:
# array([575.321483  , 569.95421992, 569.63073654, ..., 726.29225057,
#        726.32298083, 726.35371109])

# %%
forecasted_df = pd.DataFrame(forecasted_values)

# %%
test_data = test_data.set_index('Datetime')

# %%
test_data.head()
# Out:
#                         ID
# Datetime
# 2014-09-26 00:00:00  18288
# 2014-09-26 01:00:00  18289
# 2014-09-26 02:00:00  18290
# 2014-09-26 03:00:00  18291
# 2014-09-26 04:00:00  18292

# %%
test_data.index = pd.to_datetime(test_data.index, infer_datetime_format=True)

# %%
test_data.index
# Out:
# DatetimeIndex(['2014-09-26 00:00:00', '2014-09-26 01:00:00',
#                '2014-09-26 02:00:00', '2014-09-26 03:00:00',
#                '2014-09-26 04:00:00', '2014-09-26 05:00:00',
#                '2014-09-26 06:00:00', '2014-09-26 07:00:00',
#                '2014-09-26 08:00:00', '2014-09-26 09:00:00',
#                ...
#                '2015-04-26 14:00:00', '2015-04-26 15:00:00',
#                '2015-04-26 16:00:00', '2015-04-26 17:00:00',
#                '2015-04-26 18:00:00', '2015-04-26 19:00:00',
#                '2015-04-26 20:00:00', '2015-04-26 21:00:00',
#                '2015-04-26 22:00:00', '2015-04-26 23:00:00'],
#               dtype='datetime64[ns]', name='Datetime', length=5112, freq=None)

# %%
forecasted_df.index = test_data.index

# %%
forecasted_df.head()
# Out:
#                               0
# Datetime
# 2014-09-26 00:00:00  575.321483
# 2014-09-26 01:00:00  569.954220
# 2014-09-26 02:00:00  569.630737
# 2014-09-26 03:00:00  569.418607
# 2014-09-26 04:00:00  569.427258

# %%
forecasted_df.rename(columns={0: 'Count'}, inplace=True)

# %%
forecasted_df.head()
# Out:
#                           Count
# Datetime
# 2014-09-26 00:00:00  575.321483
# 2014-09-26 01:00:00  569.954220
# 2014-09-26 02:00:00  569.630737
# 2014-09-26 03:00:00  569.418607
# 2014-09-26 04:00:00  569.427258

# %%
forecasted_df.to_csv('forecast.csv')
